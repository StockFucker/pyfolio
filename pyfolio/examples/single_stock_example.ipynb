# %% [markdown]
# # Single stock analysis example in pyfolio

# %% [markdown]
# Here's a simple example where we produce a set of plots, called a tear sheet, for a stock.

# %% [markdown]
# ## Import pyfolio

# %%
# %matplotlib inline
import pyfolio as pf

# %% [markdown]
# ## Fetch the daily returns for a stock

# %%
stock_rets = pf.utils.get_symbol_rets('AAPL')

# %% [markdown]
# ## Create a full tear sheet for the single stock
# This will show charts about returns and shock events.

# %%
pf.create_returns_tear_sheet(stock_rets)
# Out:
# Entire data start date: 1993-02-02
# Entire data end date: 2016-05-17
#
#
# Backtest Months: 279
# Performance statistics   Backtest
# annual_return                0.18
# annual_volatility            0.47
# sharpe_ratio                 0.60
# calmar_ratio                 0.22
# stability_of_timeseries      0.94
# max_drawdown                -0.82
# omega_ratio                  1.12
# sortino_ratio                0.87
# skew                        -0.42
# kurtosis                    24.19
# tail_ratio                   1.11
# common_sense_ratio           1.32
# information_ratio            0.03
# alpha                        0.17
# beta                         1.07
# Worst Drawdown Periods net drawdown in %  peak date valley date recovery date  \
# 0                                  81.80 2000-03-22  2003-04-17    2005-01-26
# 1                                  77.70 1993-02-02  1997-12-23    1999-08-11
# 2                                  60.87 2007-12-28  2009-01-20    2009-10-21
# 3                                  43.80 2012-09-19  2013-04-19    2014-07-14
# 4                                  40.80 2006-01-13  2006-07-14    2006-11-16
#
# Worst Drawdown Periods duration
# 0                          1266
# 1                          1702
# 2                           474
# 3                           474
# 4                           220
# [-0.058 -0.118]
